# %% [markdown]
# ## Distribution of Rankings - Ropes & Gray

# %%
import pandas as pd
import json

df = pd.read_csv('../data/chambers_reviews_ropesandgray.csv')
df.head()
# Out:
#    publicationTypeId  publicationTypeGroupId publicationTypeDescription  \
# 0                  5                       5                        USA
# 1                  5                       5                        USA
# 2                  5                       5                        USA
# 3                  1                       1                         UK
# 4                  2                       2                     Global
#
#   departments/0/isDepartmentRanked  \
# 0                             True
# 1                             True
# 2                             True
# 3                            False
# 4                             True
#
#                            departments/0/description  \
# 0  Litigation: White-Collar Crime & Government In...
# 1  Investment Funds: Investor Representation - US...
# 2                         Healthcare - Massachusetts
# 3     Banking & Finance: Mid-Market - London (Firms)
# 4                            Banking & Finance - USA
#
#   departments/0/rankingDescription  departments/0/parentOrganisationId  \
# 0                    Up and Coming                              3650.0
# 1                           Band 3                              3650.0
# 2                    Up and Coming                              3650.0
# 3                    Up and Coming                              3650.0
# 4                           Band 4                              3650.0
#
#   departments/0/organisationName  \
# 0               Ropes & Gray LLP
# 1               Ropes & Gray LLP
# 2               Ropes & Gray LLP
# 3               Ropes & Gray LLP
# 4               Ropes & Gray LLP
#
#                departments/0/practiceAreaDescription  \
# 0  Litigation: White-Collar Crime & Government In...
# 1          Investment Funds: Investor Representation
# 2                                         Healthcare
# 3                      Banking & Finance: Mid-Market
# 4                                  Banking & Finance
#
#   departments/0/locationDescription  ...  \
# 0                     Massachusetts  ...
# 1                  USA - Nationwide  ...
# 2                     Massachusetts  ...
# 3                    London (Firms)  ...
# 4                               USA  ...
#
#    expertiseBasedAbroadDepartments/0/parentOrganisationId  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    expertiseBasedAbroadDepartments/0/organisationName  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    expertiseBasedAbroadDepartments/0/practiceAreaDescription  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    expertiseBasedAbroadDepartments/0/locationDescription  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   expertiseBasedAbroadDepartments/0/practiceAreaId  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   expertiseBasedAbroadDepartments/0/subsectionTypeId  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    expertiseBasedAbroadDepartments/0/locationId  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   expertiseBasedAbroadDepartments/0/organisationId  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   expertiseBasedAbroadDepartments/0/reviewContent/0/content/0  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   expertiseBasedAbroadDepartments/0/reviewContent/0/description
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 62 columns]

# %%
df["departments/0/rankingDescription"].unique()
# Out:
# array(['Up and Coming', 'Band 3', 'Band 4', 'Band 2', 'Band 5', 'Band 1',
#        'Eminent Practitioners', 'Spotlight Table', nan,
#        'Star Individuals', 'Band 6'], dtype=object)

# %%
order = ['Up and Coming', 'Band 6', 'Band 5', 'Band 4', 'Band 3', 'Band 2', 'Band 1', 'Star Individuals', 'Eminent Practitioners', 'Spotlight Table']
# Not sure where "Spotlight Table" should be ordered
df["departments/0/rankingDescription"].value_counts().reindex(order).plot(kind="bar")
# Out:
# <AxesSubplot:>
