# %%
import pandas as pd

df = pd.read_csv('../data/people.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  facetedSearchId  rowType  \
# 0         14584       14584                0  Lawyers
# 1         14585       14585                0  Lawyers
# 2         14586       14586                0  Lawyers
# 3         14587       14587                0  Lawyers
# 4         14588       14588                0  Lawyers
#
#                 organisationName  organisationId  organisationLocation  \
# 0                    Clayton Utz            4413                   NaN
# 1  Austrian Airlines Group (AUA)           12376                   NaN
# 2           Ana Frazão Advogados        23261592                   NaN
# 3                    Meadows Law        22964601                   NaN
# 4      Borden Ladner Gervais LLP            3759                   NaN
#
#             town    country  \
# 0         Sydney  Australia
# 1         Vienna    Austria
# 2  Brasília - DF     Brazil
# 3     St. Albert     Canada
# 4        Toronto     Canada
#
# ...

# %%
len(df.index)
# Out:
# 69331

# %%
df = df.query("organisationId == 3650", engine="python")
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)
df.head()
# Out:
#       facetedSearchId  rowType  organisationName  organisationId  \
# 247                 0  Lawyers  Ropes & Gray LLP            3650
# 427                 0  Lawyers  Ropes & Gray LLP            3650
# 787                 0  Lawyers  Ropes & Gray LLP            3650
# 1827                0  Lawyers  Ropes & Gray LLP            3650
# 1862                0  Lawyers  Ropes & Gray LLP            3650
#
#       organisationLocation      town country  \
# 247                    NaN    Boston     USA
# 427                    NaN    Boston     USA
# 787                    NaN  New York     USA
# 1827                   NaN    London      UK
# 1862                   NaN  New York     USA
#
#                                       profilePictureUrl  hasPaidProfile  \
# 247   https://media.chambers.com/individuals/3095722...            True
# 427   https://media.chambers.com/individuals/3083097...            True
# 787   https://media.chambers.com/individuals/3097018...            True
# ...

# %%
len(df.index)
# Out:
# 164

# %%
# TO DO export to CSV

# %%
df.to_csv('../data/people_ropesandgray.csv')
